# %%
#FITS File: '/users/mirandaviederman/Downloads/FITS Files/N_or_S_data/apStar-r8-2M16452941-0242588.fits'

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
import astropy
from astropy.io import fits

# %%
hduN = fits.open('/users/mirandaviederman/Downloads/FITS Files/N_data/apStar-r8-2M16452941-0242588.fits')
hduN.info()
# Out:
# Filename: /users/mirandaviederman/Downloads/FITS Files/N_data/apStar-r8-2M16452941-0242588.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     215   ()
#   1                1 ImageHDU        13   (8575, 8)   float32
#   2                1 ImageHDU        13   (8575, 8)   float32
#   3                1 ImageHDU        13   (8575, 8)   int16
#   4                1 ImageHDU        13   (8575, 8)   float32
#   5                1 ImageHDU        13   (8575, 8)   float32
#   6                1 ImageHDU        13   (8575, 8)   float32
#   7                1 ImageHDU        13   (8575, 8)   float32
#   8                1 ImageHDU        29   (26,)   float64
#   9                1 BinTableHDU     90   1R x 33C   [180A, 6I, 24A, 6J, 6I, 6D, 6E, 6E, 6E, 6E, 2I, 2E, 2E, 2E, 2E, E, E, E, E, E, 6E, 6E, 6E, 6E, 6E, 6E, 6E, 3208E, 3208E, 401E, D, D, 401E]

# %%
hduS = fits.open('/users/mirandaviederman/Downloads/FITS Files/S_data/apStar-t9-2M16452941-0242588.fits')
hduS[0].header
# Out:
# SIMPLE  =                    T /image conforms to FITS standard
# BITPIX  =                   16 /bits per data value
# NAXIS   =                    0 /number of axes
# EXTEND  =                    T /file may contain extensions
# DATE    = '2017-11-20'         / Creation UTC (CCCC-MM-DD) date of FITS header
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode 2001A&A...376..359H
# OBJID   = '2M16452941-0242588' / Object ID
# J       =              13.2570 / 2MASS J magnitude
# H       =              12.5590 / 2MASS H magnitude
# K       =              12.3880 / 2MASS Ks magnitude
# AKTARG  =      0.0696107000000 / Extinction used for targeting
# AKMETHOD= 'SFD      '          / Extinction method using for targeting
# AKWISE  =       0.235926000000 / WISE all-sky extinction
# SFD_EBV =       0.230499000000 / SFD E(B-V)
# TARG1   =          -2147397600 / First APOGEE targeting flag (bitwise, see docs)
# TARG2   =                    0 / Second APOGEE targeting flag (bitwise, see docs
# TARG3   =                    0 / Third APOGEE targeting flag (bitwise, see docs)
# SURVEY  = 'apogee2s'           / Survey name (for targeting flags)
# TELESCOP= 'lco25m  '           / Telescope
# LOCID   =                 5300 / LocationID
# FIELD   = 'M12-S   '           / Field name
# RA      =        251.372572000 / right ascension, deg, J2000
# DEC     =       -2.71634400000 / declination, deg, J2000
# GLON    =        14.7309680000 / galactic longitude, deg, J2000
# GLAT    =        26.2771336088 / galactic latitude, deg, J2000
# NVISITS =                    3 / number of visit spectra combined
# COMBTYPE=                    0 / velocities used in final combination. (0=VREL,
# COMMENT MEAN VALUES:
# VRAD    =              0.00000 / Doppler shift (km/s) of this spectrum
# VHELIO  =             -47.2288 / mean barycentric velocity (km/s)
# VSCATTER=             0.235490 / STDEV of VHELIO (km/s)
# VERR    =            0.0344263 / weighted error in VHELIO (km/s)
# VERR_MED=            0.0591170 / median error in VHELIO (km/s)
# VLSR    =       -34.1856337234 / mean LSR velocity (km/s)
# VGSR    =        15.9752795179 / mean GSR velocity (km/s)
# OVHELIO =             -47.3225 / mean barycentric velocity (km/s) from OBSVHELIO
# OVERR   =            0.0311299 / weighted error in OBSVHELIO
# OVERR_ME=            0.0532343 / median error of OBSVHELIO velocity (km/s) from
# OVSCAT  =             0.252813 / STDEV of OBSVHELIO (km/s)
# SVHELIO =             -47.2472 / mean barycentric velocity (km/s) from SYNTHVHEL
# SVERR   =            0.0257905 / weighted error in SYNTHVHELIO
# SVERR_ME=            0.0439596 / median error of SYNTHVHELIO velocity (km/s) fro
# SVSCAT  =             0.331485 / STDEV of SYNTHVHELIO (km/s)
# SYNTHSCA=            0.0953121 / STDEV of OBSVHELIO-SYNTHVHELIO (km/s)
# SNR     =              80.0108 / final median Signal/Noise ratio
# STARFLAG=                    0 / bitwise OR of individual visit starflags
# ANDFLAG =                    0 / bitwise AND of individual visit starflags
# MEANFIB =              258.490 / S/N weighted mean fiber number
# SIGFIB  =              36.4280 / standard deviation (unweighted) of fiber number
# CHISQ   =              2.78401 / chi square from mini-grid cross correlation
# RVFEH   =            -0.500000 / metallicity [Fe/H] from mini-grid cross correla
# RVTEFF  =              4000.00 / effective temperature (K) from mini-grid cross
# RVLOGG  =              3.00000 / surface gravity (dex) from mini-grid cross corr
# RVALPH  =              0.00000 / alpha abundance for mini-grid cross correlation
# RVCARB  =              0.00000 / carbon abundance for mini-grid cross correlatio
# CCPFWHM =              24.6445 / FWHM of RV CCF of star with template (km/s)
# AUTOFWHM=              22.2169 / FWHM of RV CCF of template with template (km/s)
# COMMENT VISIT 1 INFORMATION:
# SFILE1  = 'asVisit-t9-9749-57851-278.fits' / Visit #1 spectrum file
# DATE1   = '2017-04-08T08:42:46.473' / DATE-OBS of visit 1
# JD1     =        2457851.88631 / Julian date of visit 1
# HJD1    =        57851.8896879 / Reduced Heliocentric JD of visit 1
# FIBER1  =                  278 / Fiber, visit 1
# BC1     =              22.4277 / Barycentric correction (km/s),visit 1
# VTYPE1  =                    3 / RV type (1=chisq, 2=xcorr) from visit 1
# VRAD1   =             -69.4521 / Doppler shift (km/s) of visit 1
# VERR1   =            0.0636381 / error in VRAD (km/s)
# VHELIO1 =             -47.0244 / Barycentric velocity (km/s), visit 1
# CHISQ1  =              1.85641 / chi square from visit mini-grid xcorr
# RVTEFF1 =              4000.00 / effective temperature (K) from visit mini-grid
# RVLOGG1 =              3.00000 / surface gravity (dex) from visit mini-grid xcor
# RVFEH1  =            -0.500000 / metallicity [Fe/H] from visit mini-grid xcorr
# RVALPH1 =              0.00000 / alpha abundance from visit mini-grid xcorr
# RVCARB1 =              0.00000 / carbon abundance from visit mini-grid xcorr
# SNRVIS1 =              31.0439 / Signal/Noise ratio, visit 1
# FLAG1   =                    0 / STARFLAG for visit 1
# COMMENT VISIT 2 INFORMATION:
# SFILE2  = 'asVisit-t9-9750-57855-282.fits' / Visit #2 spectrum file
# DATE2   = '2017-04-12T07:08:13.937' / DATE-OBS of visit 2
# JD2     =        2457855.82065 / Julian date of visit 2
# HJD2    =        57855.8243125 / Reduced Heliocentric JD of visit 2
# FIBER2  =                  282 / Fiber, visit 2
# BC2     =              21.3255 / Barycentric correction (km/s),visit 2
# VTYPE2  =                    3 / RV type (1=chisq, 2=xcorr) from visit 2
# VRAD2   =             -68.4911 / Doppler shift (km/s) of visit 2
# VERR2   =            0.0591170 / error in VRAD (km/s)
# VHELIO2 =             -47.1656 / Barycentric velocity (km/s), visit 2
# CHISQ2  =              1.97396 / chi square from visit mini-grid xcorr
# RVTEFF2 =              4000.00 / effective temperature (K) from visit mini-grid
# RVLOGG2 =              3.00000 / surface gravity (dex) from visit mini-grid xcor
# RVFEH2  =            -0.500000 / metallicity [Fe/H] from visit mini-grid xcorr
# RVALPH2 =              0.00000 / alpha abundance from visit mini-grid xcorr
# RVCARB2 =              0.00000 / carbon abundance from visit mini-grid xcorr
# SNRVIS2 =              32.1568 / Signal/Noise ratio, visit 2
# FLAG2   =                    0 / STARFLAG for visit 2
# COMMENT VISIT 3 INFORMATION:
# SFILE3  = 'asVisit-t9-9751-57914-217.fits' / Visit #3 spectrum file
# DATE3   = '2017-06-10T02:28:26.036' / DATE-OBS of visit 3
# JD3     =        2457914.62635 / Julian date of visit 3
# HJD3    =        57914.6318107 / Reduced Heliocentric JD of visit 3
# FIBER3  =                  217 / Fiber, visit 3
# BC3     =             -3.82293 / Barycentric correction (km/s),visit 3
# VTYPE3  =                    3 / RV type (1=chisq, 2=xcorr) from visit 3
# VRAD3   =             -43.6612 / Doppler shift (km/s) of visit 3
# VERR3   =            0.0562689 / error in VRAD (km/s)
# VHELIO3 =             -47.4841 / Barycentric velocity (km/s), visit 3
# CHISQ3  =              2.27673 / chi square from visit mini-grid xcorr
# RVTEFF3 =              4000.00 / effective temperature (K) from visit mini-grid
# RVLOGG3 =              3.00000 / surface gravity (dex) from visit mini-grid xcor
# RVFEH3  =            -0.500000 / metallicity [Fe/H] from visit mini-grid xcorr
# RVALPH3 =              0.00000 / alpha abundance from visit mini-grid xcorr
# RVCARB3 =              0.00000 / carbon abundance from visit mini-grid xcorr
# SNRVIS3 =              32.8189 / Signal/Noise ratio, visit 3
# FLAG3   =                    0 / STARFLAG for visit 3
# RMIN    =                 6316 / Min pixel of red chip contrib, any frame
# RMAX    =                 8398 / Maxmm pixel of red chip contrib, any frame
# GMIN    =                 3534 / Min pixel of green chip contrib, any frame
# GMAX    =                 6123 / Maxm pixel of green chip contrib, any frame
# BMIN    =                  171 / Min pixel of blue chip contrib, any frame
# BMAX    =                 3293 / Maxm pixel of blue chip contrib, any frame
# ROVERMIN=                 6324 / Min pixel of red chip contrib, all frames
# ROVERMAX=                 8392 / Max pixel of red chip contrib, all frames
# GOVERMIN=                 3544 / Min pixel of green chip contrib, all frames
# GOVERMAX=                 6116 / Max pixel of green chip contrib, all frames
# BOVERMIN=                  180 / Minimum pixel of blue chip contrib, all frames
# BOVERMAX=                 3285 / Maximum pixel of blue chip contrib, all frames
# COMMENT Wavelength polynomial coefficients (Ang):
# NWAVE   =                 8575 /Number of wavelengths in subsequent HDUs
# CRVAL1  =        4.17900000000 /Start log10(wavelength) in subsequent HDUs
# CDELT1  =    6.00000000000E-06 /Dispersion in log10(wavelength) in subsequent HD
# CRPIX1  =                    1 /Pixel of starting wavelength in subsequent HDUs
# CTYPE1  = 'LOG-LINEAR'         /Logarithmic wavelength scale in subsequent HDUs
# DC-FLAG =                    1 /Logarithmic wavelength scale in subsequent HDUs
# HISTORY APSTAR: Mon Nov 20 01:52:18 2017
# HISTORY APSTAR: apogee on kp135
# HISTORY APSTAR: IDL 8.5.1 linux x86_64
# HISTORY APSTAR:  APOGEE Reduction Pipeline Version: 4.0.2
# HISTORY APSTAR: The data are in separate extensions:
# HISTORY APSTAR:  HDU0 = Header only
# HISTORY APSTAR:  All image extensions have:
# HISTORY APSTAR:    row 1: combined spectrum with individual pixel weighting
# HISTORY APSTAR:    row 2: combined spectrum with global weighting
# HISTORY APSTAR:    row 3-nvisits+2: individual resampled visit spectra
# HISTORY APSTAR:   unless nvisits=1, which only have a single row
# HISTORY APSTAR:  All spectra shifted to rest (vacuum) wavelength scale
# HISTORY APSTAR:  HDU1 - Flux (10^-17 ergs/s/cm^2/Ang)
# HISTORY APSTAR:  HDU2 - Error (10^-17 ergs/s/cm^2/Ang)
# HISTORY APSTAR:  HDU3 - Flag mask:
# HISTORY APSTAR:    row 1: bitwise OR of all visits
# HISTORY APSTAR:    row 2: bitwise AND of all visits
# HISTORY APSTAR:    row 3-nvisits+2: individual visit masks
# HISTORY APSTAR:  HDU4 - Sky (10^-17 ergs/s/cm^2/Ang)
# HISTORY APSTAR:  HDU5 - Sky Error (10^-17 ergs/s/cm^2/Ang)
# HISTORY APSTAR:  HDU6 - Telluric
# HISTORY APSTAR:  HDU7 - Telluric Error
# HISTORY APSTAR:  HDU8 - LSF coefficients
# HISTORY APSTAR:  HDU9 - RV and CCF structure

# %% [markdown]
#    ## Comparative Plot

# %% [markdown]
# #### North

# %%
fluxesN = np.atleast_2d(hduN[1].data)
NexpN, NpixN = fluxesN.shape
wavelengthsN = 10. ** (hduN[0].header["CRVAL1"] + hduN[0].header["CDELT1"] * np.arange(NpixN))

# %% [markdown]
# #### South

# %%
fluxesS = np.atleast_2d(hduS[1].data)
NexpS, NpixS = fluxesS.shape
wavelengthsS = 10 ** (hduS[0].header["CRVAL1"] + hduS[0].header["CDELT1"] * np.arange(NpixS))

# %% [markdown]
# ### Plotting

# %%
for exp in range(NexpN): #NORTH
    plt.step(wavelengthsN, 20*exp+fluxesN[exp], color="b", linewidth=.4, alpha=.5)

for exp in range(NexpS): #SOUTH
    plt.step(wavelengthsS, 20*exp+fluxesS[exp]+200, color="r", linewidth=0.4, alpha=.5)
    
#label = 'Exposure number: '+str(exp+1) --> 
    #find way to separate legends so that Northern data exposure numbers and 
    #Southern data exposure numbers can be easily distinguished

plt.ylabel(r'Flux [$10^{-17}$ erg/cm$^2$/s/Å]')
plt.xlabel("Wavelength in Ångstroms")
plt.title('Comparative Plot of Northern and Southern Stellar Spectra Data')

plt.legend(label='Data Source Telescope', loc='best', fontsize=8 )

#plt.ylim(0,500);
#plt.xlim(15250,15300);
#plt.xlim(16000,16100);
#plt.xlim(15750,15900);
# Out:
# <img src="data:image/png;base64,..." width="640">
