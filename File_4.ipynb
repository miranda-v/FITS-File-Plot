# %%
#FITS File 4 = ('/users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M05580827+1345138.fits')

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
import astropy
from astropy.io import fits

# %%
hdu4 = fits.open('/users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M05580827+1345138.fits')
hdu4.info()
# Out:
# Filename: /users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M05580827+1345138.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     215   ()
#   1                1 ImageHDU        13   (8575, 8)   float32
#   2                1 ImageHDU        13   (8575, 8)   float32
#   3                1 ImageHDU        13   (8575, 8)   int16
#   4                1 ImageHDU        13   (8575, 8)   float32
#   5                1 ImageHDU        13   (8575, 8)   float32
#   6                1 ImageHDU        13   (8575, 8)   float32
#   7                1 ImageHDU        13   (8575, 8)   float32
#   8                1 ImageHDU        29   (26,)   float64
#   9                1 BinTableHDU     90   1R x 33C   [180A, 6I, 24A, 6J, 6I, 6D, 6E, 6E, 6E, 6E, 2I, 2E, 2E, 2E, 2E, E, E, E, E, E, 6E, 6E, 6E, 6E, 6E, 6E, 6E, 3208E, 3208E, 401E, D, D, 401E]

# %% [markdown]
# ## Plot

# %%
fluxes = np.atleast_2d(hdu4[1].data)
Nexp, Npix = fluxes.shape
wavelengths = 10. ** (hdu4[0].header["CRVAL1"] + hdu4[0].header["CDELT1"] * np.arange(Npix))
plt.clf()
for exp in range(Nexp):
    plt.step(wavelengths, 100*exp+fluxes[exp], label = 'Exposure number: '+str(exp+1), linewidth = .5, alpha = .7)
plt.ylabel(r'Flux [$10^{-17}$ erg/cm$^2$/s/Å]')
plt.xlabel("Wavelength in Ångstroms")
plt.legend(loc='best', ncol=2, fontsize=8)
plt.title('APOGEE ID 2M05580827+1345138');
#plt.xlim(15500, 15700);
# Out:
# <img src="data:image/png;base64,..." width="722">
