# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import numpy as np
# %config InlineBackend.rc = {'figure.figsize': (8.0, 6.0)}
# %config InlineBackend.figure_format = 'retina'
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import astropy

# %%
from astropy.io import fits

# %%
#from astropy.utils.data import get_readable_fileobj

# %%
fits1_image = ('/users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M13384267+2723430.fits')
fits2_image = ('/users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M13072813+1653414.fits')
fits3_image = ('/users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M08463782+5729103.fits')
fits4_image = ('/users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M05580827+1345138.fits')

# %%
###retrieve HDU info from other notebook so you can isolate and understand important items in future

# %%
hdu1 = fits.open('/users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M13384267+2723430.fits')
hdu1.info()
# Out:
# Filename: /users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M13384267+2723430.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     120   ()
#   1                1 ImageHDU        12   (8575,)   float32
#   2                1 ImageHDU        12   (8575,)   float32
#   3                1 ImageHDU        12   (8575,)   int16
#   4                1 ImageHDU        12   (8575,)   float32
#   5                1 ImageHDU        12   (8575,)   float32
#   6                1 ImageHDU        12   (8575,)   float32
#   7                1 ImageHDU        12   (8575,)   float32
#   8                1 ImageHDU        29   (26,)   float64
#   9                1 BinTableHDU     83   1R x 33C   [30A, I, 4A, J, I, D, E, E, E, E, 2I, 2E, 2E, 2E, 2E, E, E, E, E, E, E, E, E, E, E, E, E, 401E, 401E, 401E, D, D, 401E]

# %%
hdu1[0].header
# Out:
# SIMPLE  =                    T /image conforms to FITS standard
# BITPIX  =                   16 /bits per data value
# NAXIS   =                    0 /number of axes
# EXTEND  =                    T /file may contain extensions
# DATE    = '2016-12-13'         / Creation UTC (CCCC-MM-DD) date of FITS header
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode 2001A&A...376..359H
# OBJID   = '2M13384267+2723430' / Object ID
# J       =              11.2610 / 2MASS J magnitude
# H       =              10.6790 / 2MASS H magnitude
# K       =              10.4120 / 2MASS Ks magnitude
# AKTARG  =       -99.0000000000 / Extinction used for targeting
# AKMETHOD= 'none    '           / Extinction method using for targeting
# AKWISE  =       -99.0000000000 / WISE all-sky extinction
# SFD_EBV =       -99.0000000000 / SFD E(B-V)
# ...

# %%
fluxes = np.atleast_2d(hdu1[1].data)
Nexp, Npix = fluxes.shape
wavelengths = 10. ** (hdu1[0].header["CRVAL1"] + hdu1[0].header["CDELT1"] * np.arange(Npix))
plt.clf()
for exp in range(Nexp):
    plt.step(wavelengths, fluxes[exp])
plt.ylabel("flux")
plt.xlabel("wavelength")
# Out:
# Text(0.5,0,'wavelength')

# %%
hdu1 = fits.open('/users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M13072813+1653414.fits')
fluxes = np.atleast_2d(hdu1[1].data)
Nexp, Npix = fluxes.shape
wavelengths = 10. ** (hdu1[0].header["CRVAL1"] + hdu1[0].header["CDELT1"] * np.arange(Npix))
plt.clf()
for exp in range(Nexp):
    plt.step(wavelengths, fluxes[exp] + 100 * exp, alpha=0.25)
plt.ylabel("flux")
plt.xlabel("wavelength")
plt.xlim(15200, 15220)
# Out:
# (15200, 15220)

# %%
hdu3 = fits.open('/users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M08463782+5729103.fits')
hdu3.info()
# Out:
# Filename: /users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M08463782+5729103.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     139   ()
#   1                1 ImageHDU        13   (8575, 4)   float32
#   2                1 ImageHDU        13   (8575, 4)   float32
#   3                1 ImageHDU        13   (8575, 4)   int16
#   4                1 ImageHDU        13   (8575, 4)   float32
#   5                1 ImageHDU        13   (8575, 4)   float32
#   6                1 ImageHDU        13   (8575, 4)   float32
#   7                1 ImageHDU        13   (8575, 4)   float32
#   8                1 ImageHDU        29   (26,)   float64
#   9                1 BinTableHDU     90   1R x 33C   [62A, 2I, 10A, 2J, 2I, 2D, 2E, 2E, 2E, 2E, 2I, 2E, 2E, 2E, 2E, E, E, E, E, E, 2E, 2E, 2E, 2E, 2E, 2E, 2E, 1604E, 1604E, 401E, D, D, 401E]

# %%
hdu4 = fits.open('/users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M05580827+1345138.fits')
hdu4[10].header
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-654158e3d6a6> in <module>()
#       1 hdu4 = fits.open('/users/mirandaviederman/Downloads/FITS Files/apStar-r8-2M05580827+1345138.fits')
# ----> 2 hdu4[10].header
#
# /anaconda3/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in __getitem__(self, key)
#     317             # Raise a more helpful IndexError if the file was not fully read.
#     318             if self._read_all:
# --> 319                 raise e
#     320             else:
#     321                 raise IndexError('HDU not found, possibly because the index '
#
# /anaconda3/lib/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in __getitem__(self, key)
#     313         try:
#     314             return self._try_while_unread_hdus(super(HDUList, self).__getitem__,
# ...

# %%
plot1 = hdu1[1].data
plot2 = hdu2[1].data
plot3 = hdu3[1].data
plot4 = hdu4[1].data

# %% [markdown]
# ### here are my plots

# %% [markdown]
# ##### notes:
#
# take a look at laTex formatting.

# %%
from matplotlib.pyplot import savefig

# %%
from matplotlib.pyplot import savefig
fig1 = plt.step(plot1, linewidth = 0.4, label = 'APOGEE ID 2M13384267+2723430')
plt.xlabel('Wavelength [Ångströms]')
plt.ylabel(r'Flux [$10^{-17}$ erg/cm$^2$/s/Å]')
plt.legend();

matplotlib.pyplot.savefig('/Users/mirandaviederman/Desktop/test1.pdf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-746bd4922616> in <module>()
#       1 from matplotlib.pyplot import savefig
# ----> 2 fig1 = plt.step(plot1, linewidth = 0.4, label = 'APOGEE ID 2M13384267+2723430')
#       3 plt.xlabel('Wavelength [Ångströms]')
#       4 plt.ylabel(r'Flux [$10^{-17}$ erg/cm$^2$/s/Å]')
#       5 plt.legend();
#
# TypeError: step() missing 1 required positional argument: 'y'

# %%
fig2 = plt.plot(plot2, linewidth=0.4, label='APOGEE ID 2M13072813+1653414')
plt.xlabel('Wavelength [Ångströms]')
plt.ylabel(r'Flux [$10^{-17}$ erg/cm$^2$/s/Å]')
plt.legend();

matplotlib.pyplot.savefig('/Users/mirandaviederman/Desktop/test2.pdf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     330                 pass
#     331             else:
# --> 332                 return printer(obj)
#     333             # Finally look for special method names
#     334             method = get_real_method(obj, self.print_method)
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     237         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     238     if 'retina' in formats or 'png2x' in formats:
# --> 239         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#     240     if 'jpg' in formats or 'jpeg' in formats:
#     241         jpg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'jpg', **kwargs))
#
# ...

# %%
fig3 = plt.plot(plot3, linewidth=0.4, label='APOGEE ID 2M08463782+5729103')
plt.xlabel('Wavelength [Ångströms]')
plt.ylabel(r'Flux [$10^{-17}$ erg/cm$^2$/s/Å]')
plt.legend();

matplotlib.pyplot.savefig('/Users/mirandaviederman/Desktop/test3.pdf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     330                 pass
#     331             else:
# --> 332                 return printer(obj)
#     333             # Finally look for special method names
#     334             method = get_real_method(obj, self.print_method)
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     237         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     238     if 'retina' in formats or 'png2x' in formats:
# --> 239         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#     240     if 'jpg' in formats or 'jpeg' in formats:
#     241         jpg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'jpg', **kwargs))
#
# ...

# %%
fig4 = plt.plot(plot4, linewidth=0.4, label='APOGEE ID 2M05580827+1345138')
plt.xlabel('Wavelength [Ångströms]')
plt.ylabel(r'Flux [$10^{-17}$ erg/cm$^2$/s/Å]')
plt.legend();

matplotlib.pyplot.savefig('/Users/mirandaviederman/Desktop/test4.pdf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     330                 pass
#     331             else:
# --> 332                 return printer(obj)
#     333             # Finally look for special method names
#     334             method = get_real_method(obj, self.print_method)
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     237         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     238     if 'retina' in formats or 'png2x' in formats:
# --> 239         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#     240     if 'jpg' in formats or 'jpeg' in formats:
#     241         jpg_formatter.for_type(Figure, lambda fig: print_figure(fig, 'jpg', **kwargs))
#
# ...
